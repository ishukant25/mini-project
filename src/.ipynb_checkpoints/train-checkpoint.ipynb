# %%
# train.py

import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import joblib

def load_processed_data():
    """
    Load the preprocessed training and testing data.
    """
    X_train = np.load('../data/processed/X_train.npy')
    X_test = np.load('../data/processed/X_test.npy')
    y_train = np.load('../data/processed/y_train.npy')
    y_test = np.load('../data/processed/y_test.npy')
    return X_train, X_test, y_train, y_test

def build_densenet128(input_shape):
    """
    Build the DenseNet128 model.
    """
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_shape,)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

def train_densenet128(X_train, y_train, X_test, y_test):
    """
    Train the DenseNet128 model and save it.
    """
    model = build_densenet128(X_train.shape[1])
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
    model.save('../models/densenet128_model.h5')
    return model, history

def train_enhanced_rf(X_train, y_train):
    """
    Train the Enhanced Random Forest model and save it.
    """
    rf_model = RandomForestClassifier(n_estimators=200, max_depth=None, min_samples_split=2, random_state=42)
    rf_model.fit(X_train, y_train)
    joblib.dump(rf_model, '../models/enhanced_rf_model.pkl')
    return rf_model

def evaluate_model(model, X_test, y_test, model_type='densenet128'):
    """
    Evaluate the model on the test set and print metrics.
    """
    if model_type == 'densenet128':
        y_pred = (model.predict(X_test) > 0.5).astype(int)
    else:
        y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print(f"{model_type} Model Evaluation:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1-Score: {f1:.4f}")

def main():
    # Load the preprocessed data
    X_train, X_test, y_train, y_test = load_processed_data()

    # Train the DenseNet128 model
    print("Training DenseNet128 model...")
    densenet128_model, history = train_densenet128(X_train, y_train, X_test, y_test)
    evaluate_model(densenet128_model, X_test, y_test, model_type='densenet128')

    # Train the Enhanced Random Forest model
    print("Training Enhanced Random Forest model...")
    rf_model = train_enhanced_rf(X_train, y_train)
    evaluate_model(rf_model, X_test, y_test, model_type='enhanced_rf')

    print("Model training and evaluation completed.")

if __name__ == "__main__":
    main()
# Out:
# Training DenseNet128 model...
# C:\Users\mdaas\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7331 - loss: 0.5814 - val_accuracy: 0.9341 - val_loss: 0.3315
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9174 - loss: 0.3255 - val_accuracy: 0.9451 - val_loss: 0.1809
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9513 - loss: 0.1695 - val_accuracy: 0.9560 - val_loss: 0.1253
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9612 - loss: 0.1162 - val_accuracy: 0.9670 - val_loss: 0.1022
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9720 - loss: 0.0952 - val_accuracy: 0.9780 - val_loss: 0.0932
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9803 - loss: 0.0690 - val_accuracy: 0.9780 - val_loss: 0.0899
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9896 - loss: 0.0657 - val_accuracy: 0.9670 - val_loss: 0.0884
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9748 - loss: 0.0705 - val_accuracy: 0.9670 - val_loss: 0.0907
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9734 - loss: 0.0681 - val_accuracy: 0.9451 - val_loss: 0.0922
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9828 - loss: 0.0694 - val_accuracy: 0.9451 - val_loss: 0.0902
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9933 - loss: 0.0426 - val_accuracy: 0.9670 - val_loss: 0.0846
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9915 - loss: 0.0449 - val_accuracy: 0.9780 - val_loss: 0.0845
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9921 - loss: 0.0407 - val_accuracy: 0.9780 - val_loss: 0.0778
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9826 - loss: 0.0591 - val_accuracy: 0.9670 - val_loss: 0.0775
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9885 - loss: 0.0376 - val_accuracy: 0.9670 - val_loss: 0.0761
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9927 - loss: 0.0291 - val_accuracy: 0.9780 - val_loss: 0.0724
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9909 - loss: 0.0193 - val_accuracy: 0.9890 - val_loss: 0.0729
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9941 - loss: 0.0211 - val_accuracy: 0.9780 - val_loss: 0.0744
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9973 - loss: 0.0163 - val_accuracy: 0.9560 - val_loss: 0.0936
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9982 - loss: 0.0243 - val_accuracy: 0.9670 - val_loss: 0.0887
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9884 - loss: 0.0366 - val_accuracy: 0.9670 - val_loss: 0.0836
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9813 - loss: 0.0409 - val_accuracy: 0.9890 - val_loss: 0.0695
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9916 - loss: 0.0272 - val_accuracy: 0.9780 - val_loss: 0.0662
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9920 - loss: 0.0297 - val_accuracy: 0.9780 - val_loss: 0.0698
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9948 - loss: 0.0214 - val_accuracy: 0.9780 - val_loss: 0.0710
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9958 - loss: 0.0136 - val_accuracy: 0.9780 - val_loss: 0.0717
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9902 - loss: 0.0213 - val_accuracy: 0.9780 - val_loss: 0.0727
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9949 - loss: 0.0161 - val_accuracy: 0.9780 - val_loss: 0.0743
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9914 - loss: 0.0317 - val_accuracy: 0.9780 - val_loss: 0.0657
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9905 - loss: 0.0186 - val_accuracy: 0.9890 - val_loss: 0.0690
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9973 - loss: 0.0152 - val_accuracy: 0.9780 - val_loss: 0.0751
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9976 - loss: 0.0101 - val_accuracy: 0.9890 - val_loss: 0.0846
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9907 - loss: 0.0219 - val_accuracy: 0.9780 - val_loss: 0.0737
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9994 - loss: 0.0084 - val_accuracy: 0.9780 - val_loss: 0.0725
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9950 - loss: 0.0101 - val_accuracy: 0.9780 - val_loss: 0.0770
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9973 - loss: 0.0063 - val_accuracy: 0.9780 - val_loss: 0.0790
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9961 - loss: 0.0134 - val_accuracy: 0.9780 - val_loss: 0.0803
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9973 - loss: 0.0111 - val_accuracy: 0.9780 - val_loss: 0.0827
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.9780 - val_loss: 0.0834
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9780 - val_loss: 0.0843
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9896 - loss: 0.0275 - val_accuracy: 0.9780 - val_loss: 0.0876
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9971 - loss: 0.0081 - val_accuracy: 0.9780 - val_loss: 0.0841
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9973 - loss: 0.0085 - val_accuracy: 0.9780 - val_loss: 0.0776
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9859 - loss: 0.0201 - val_accuracy: 0.9780 - val_loss: 0.0846
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9986 - loss: 0.0117 - val_accuracy: 0.9780 - val_loss: 0.0892
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9986 - loss: 0.0057 - val_accuracy: 0.9780 - val_loss: 0.0894
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9923 - loss: 0.0247 - val_accuracy: 0.9780 - val_loss: 0.0870
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9958 - loss: 0.0212 - val_accuracy: 0.9670 - val_loss: 0.1273
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.9670 - val_loss: 0.1297
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9923 - loss: 0.0154 - val_accuracy: 0.9670 - val_loss: 0.1131
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9780 - val_loss: 0.1094
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9670 - val_loss: 0.1144
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9960 - loss: 0.0053 - val_accuracy: 0.9670 - val_loss: 0.1170
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9780 - val_loss: 0.1062
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9994 - loss: 0.0085 - val_accuracy: 0.9780 - val_loss: 0.0871
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9780 - val_loss: 0.0787
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9933 - loss: 0.0138 - val_accuracy: 0.9670 - val_loss: 0.0908
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9917 - loss: 0.0195 - val_accuracy: 0.9670 - val_loss: 0.1010
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9994 - loss: 0.0051 - val_accuracy: 0.9780 - val_loss: 0.1051
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9982 - loss: 0.0047 - val_accuracy: 0.9780 - val_loss: 0.1134
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.9780 - val_loss: 0.1159
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9982 - loss: 0.0081 - val_accuracy: 0.9780 - val_loss: 0.0961
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9780 - val_loss: 0.0829
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9780 - val_loss: 0.0823
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9780 - val_loss: 0.0872
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9780 - val_loss: 0.0922
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9670 - val_loss: 0.1130
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9670 - val_loss: 0.1596
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9670 - val_loss: 0.1821
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9670 - val_loss: 0.1808
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9670 - val_loss: 0.1215
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.8769e-04 - val_accuracy: 0.9670 - val_loss: 0.1077
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9780 - val_loss: 0.1002
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9949 - loss: 0.0078 - val_accuracy: 0.9780 - val_loss: 0.1006
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.9780 - val_loss: 0.1068
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9780 - val_loss: 0.1082
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9780 - val_loss: 0.1040
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9780 - val_loss: 0.0983
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9967 - loss: 0.0047 - val_accuracy: 0.9780 - val_loss: 0.1032
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9780 - val_loss: 0.1105
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9959 - loss: 0.0120 - val_accuracy: 0.9670 - val_loss: 0.1190
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9560 - val_loss: 0.1598
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9973 - loss: 0.0031 - val_accuracy: 0.9560 - val_loss: 0.1795
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9560 - val_loss: 0.1851
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9560 - val_loss: 0.1615
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 6.7535e-04 - val_accuracy: 0.9780 - val_loss: 0.1396
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 6.9729e-04 - val_accuracy: 0.9780 - val_loss: 0.1396
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9989 - loss: 0.0019 - val_accuracy: 0.9560 - val_loss: 0.1494
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.0454e-04 - val_accuracy: 0.9560 - val_loss: 0.1658
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9780 - val_loss: 0.1365
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.9780 - val_loss: 0.1344
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9923 - loss: 0.0083 - val_accuracy: 0.9780 - val_loss: 0.1232
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9780 - val_loss: 0.1228
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9780 - val_loss: 0.1311
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9780 - val_loss: 0.1336
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 5.9003e-04 - val_accuracy: 0.9780 - val_loss: 0.1342
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 9.8662e-04 - val_accuracy: 0.9780 - val_loss: 0.1336
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9982 - loss: 0.0018 - val_accuracy: 0.9780 - val_loss: 0.1379
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.9780 - val_loss: 0.1384
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9780 - val_loss: 0.1282
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# densenet128 Model Evaluation:
# Accuracy: 0.9561
# Precision: 0.9318
# Recall: 0.9535
# F1-Score: 0.9425
# Training Enhanced Random Forest model...
# enhanced_rf Model Evaluation:
# Accuracy: 0.9649
# Precision: 0.9756
# Recall: 0.9302
# F1-Score: 0.9524
# Model training and evaluation completed.
